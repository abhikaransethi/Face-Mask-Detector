# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions

# %%
from tensorflow.keras.preprocessing import image

# %%
from keras.preprocessing import image

# %%
model=VGG16(weights='imagenet', include_top=False, input_shape=(224, 224,3))

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
model2=MobileNetV2(weights='imagenet')
# Out:
# ...
# 14540800/14536120 [==============================] - 2s 0us/step

# %%
model2.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
img_path='dataset'

# %%
img=image.load_img(img_path, color_mode='rgb', target_size=(224,224))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2C4E421A910>

# %%
x=image.img_to_array(img)
x=np.expand_dims(x, axis=0)

# %%
features=model.predict(preprocess_input(x))

# %%
decode_predictions(features,top=3)
# Out:
# [[('n04229816', 'ski_mask', 0.9220626),
#   ('n03724870', 'mask', 0.075196974),
#   ('n02667093', 'abaya', 0.0024446372)]]

# %%
image_gen=ImageDataGenerator(rescale=1./255, horizontal_flip=True, rotation_range=20,zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2, validation_split=0.2,preprocessing_function=preprocess_input)

# %%
x_train=image_gen.flow_from_directory('dataset', target_size=(224, 224), batch_size=32, class_mode='binary', subset='training')
# Out:
# Found 3067 images belonging to 2 classes.

# %%
x_train.class_indices
# Out:
# {'with_mask': 0, 'without_mask': 1}

# %%
x_test=image_gen.flow_from_directory('dataset', target_size=(224, 224), batch_size=32, class_mode='binary', subset='validation')
# Out:
# Found 766 images belonging to 2 classes.

# %%
from sklearn.model_selection import train_test_split

# %%
(x_train ,  x_test)=train_test_split(X, test_size=0.20, random_state=42)

# %%
finalmodel=Sequential()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3576/1441582951.py in <module>
# ----> 1 finalmodel=Sequential()
#
# NameError: name 'Sequential' is not defined

# %%
from tensorflow.keras.models import Sequential

# %%
finalmodel=Sequential()
for layer in model.layers:
    
    finalmodel.add(layer)

# %%
finalmodel.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# ...

# %%
from keras.layers import Flatten

# %%
for layer in finalmodel.layers:
    layer.trainable=False

# %%
finalmodel.add(Flatten())

# %%
from tensorflow.keras.layers import Dense

# %%
# finalmodel.add(Dense(128, activation='relu'))
finalmodel.add(Dense(1, activation='softmax'))

# %%
finalmodel.compile(Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.optimizers import Adam

# %%
result=finalmodel.fit(x_train, epochs=10, steps_per_epoch=30, validation_data= x_test, validation_steps=10)
# Out:
# Epoch 1/10
# 30/30 [==============================] - 202s 7s/step - loss: 0.4092 - accuracy: 0.5225 - val_loss: 0.2605 - val_accuracy: 0.5000
# Epoch 2/10
# 30/30 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.5010
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3576/2023741452.py in <module>
# ----> 1 result=finalmodel.fit(x_train, epochs=10, steps_per_epoch=30, validation_data= x_test, validation_steps=10)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1212                 model=self,
# ...

# %%
x_train[0]
# Out:
# (array([[[[-0.30956474, -0.32462355, -0.33600003],
#           [-0.29996735, -0.3194557 , -0.33083218],
#           [-0.25858435, -0.29717258, -0.30854905],
#           ...,
#           [-0.25466278, -0.3324667 , -0.37129414],
#           [-0.25747272, -0.3324667 , -0.36942083],
#           [-0.2664275 , -0.3324667 , -0.363451  ]],
#
#          [[-0.30956474, -0.32462355, -0.33600003],
#           [-0.3093173 , -0.3244903 , -0.33586678],
#           [-0.26547632, -0.30088365, -0.31226012],
#           ...,
#           [-0.25596902, -0.33377293, -0.37260038],
#           [-0.2576924 , -0.33491594, -0.37330854],
#           [-0.26398468, -0.33279493, -0.36444277]],
#
#          [[-0.31016877, -0.3252276 , -0.33660406],
#           [-0.30956474, -0.32462355, -0.33600003],
#           [-0.27482632, -0.30591822, -0.3172947 ],
#           ...,
#           [-0.26250592, -0.34030983, -0.37913728],
#           [-0.26250592, -0.34030983, -0.37913728],
# ...

# %%
pd.DataFrame(X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3576/73902398.py in <module>
# ----> 1 pd.DataFrame(X)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     561         elif isinstance(data, abc.Iterable) and not isinstance(data, (str, bytes)):
#     562             if not isinstance(data, (abc.Sequence, ExtensionArray)):
# --> 563                 data = list(data)
#     564             if len(data) > 0:
#     565                 if is_dataclass(data[0]):
#
# ~\anaconda3\lib\site-packages\keras_preprocessing\image\iterator.py in __next__(self, *args, **kwargs)
#     102
#     103     def __next__(self, *args, **kwargs):
# --> 104         return self.next(*args, **kwargs)
#     105
#     106     def next(self):
#
# ...

# %%
import pandas as pd
